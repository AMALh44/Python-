# %%
a = int(input('Enter the first number:'))
b = int(input('Enter the second number:'))
c = a/b
print(c)
# Out:
# Enter the first number:40
# Enter the second number:7
# 5.714285714285714

# %% [markdown]
# The try and except blocks in Python are used for handling exceptions—errors that occur during the execution of a program. This feature allows you to gracefully manage errors without stopping the program abruptly.

# %% [markdown]
# # Type of Errors

# %% [markdown]
# **ZeroDivisionError**

# %%
try:
  a = int(input('Enter the first number:'))
  b = int(input('Enter the second number:'))
  c = a/b
  print(c)

except:
   print("enter the valid number")
# Out:
# Enter the first number:6
# Enter the second number:0
# enter the valid number

# %% [markdown]
# **Index Error**

# %%
try:
  index = [1,2,3,4,5]
  print(index[8])
except:
   print("index is out of range")
# Out:
# index is out of range

# %% [markdown]
# **Key Error**

# %%
try:
  dict1 = {a:'1',b:'2'}
  print(dict1['c'])
except:
   print("it's a key error")
# Out:
# it's a key error

# %% [markdown]
# **Type Error**

# %%
try:
  print("2" + 3)

except:
   print("Type error")
# Out:
# Type error

# %% [markdown]
# **Value Error**

# %%
try:
  a = int(input('Enter the first number:'))
  b = int(input('Enter the second number:'))
  c = a/b
  print(c)

except:
   print("Value Error")
# Out:
# Enter the first number:12
# Enter the second number:s
# Value Error

# %% [markdown]
# # Handling Specific Exception

# %%
try:
  a = int(input('Enter the first number:'))
  b = int(input('Enter the second number:'))
  c = a/b
  print(c)

except ZeroDivisionError:
   print("Zero Division Error")

except ValueError:
   print("Value Error")
# Out:
# Enter the first number:5
# Enter the second number:h
# Value Error

# %% [markdown]
# * An exception in Python is an event that occurs during the execution of a program and disrupts its normal flow. Exceptions are Python's way of signaling that an error or an unexpected condition has been encountered

# %%
try:
  a = int(input('Enter the first number:'))
  b = int(input('Enter the second number:'))
  c = a/b
  print(c)
except Exception as e:
   print("Something Went wrong:",e)
# Out:
# Enter the first number:5
# Enter the second number:0
# Something Went wrong: division by zero

# %% [markdown]
# # else

# %%
try:
  a = int(input())
  b = int(input())
  c= a/b
  print(c)

except:
  print("enter valid number")

else:
  print("code completed")
# Out:
# 3
# 5
# 0.6
# code completed

# %% [markdown]
# # finally

# %%
# it work's both error and non-error

try:
  a = int(input())
  b = int(input())
  c= a/b
  print(c)
finally:
  print('end')
# Out:
# 6
# 7
# 0.8571428571428571
# end

# %% [markdown]
# # Using While Loop

# %%
while True:
  try:
    a = int(input())
    b = int(input())
    c= a/b
  except:
    print("enter valid number")
  else:
    print("\nResult:",c)
    break
# Out:
# 4
# h
# enter valid number
# 5
# 0
# enter valid number
# 8
# 4
#
# Result: 2.0

# %%
while True:
  try:
    a = int(input())
    b = int(input())
    c= a/b

  except ZeroDivisionError:
    print("Zero Division Error")

  except ValueError:
    print("Value Error")
  else:
    print("\nResult:",c)
    break
# Out:
# 5
# 0
# Zero Division Error
# 4
# h
# Value Error
# 5
# 5
#
# Result: 1.0

# %%
try:
   # Outer try block to handle user input
   a = int(input("Enter the number:"))
   b = int(input("Enter the number:"))

   try:
      # Inner try block to handle division
      c = a/b
      print(f"result:{c}")
   except ZeroDivisionError:
      print("-Cannot divide by zero")
   finally:
      print("-Inner Block Finished")

except ValueError:
   print("-Invalid input:please enter integer only.")
finally:
   print("-Outer block Finished")
# Out:
# Enter the number:4
# Enter the number:5
# result:0.8
# -Inner Block Finished
# -Outer block Finished

# %% [markdown]
# # raise

# %%
x = int(input())

if  x < 0:
  raise Exception("sorry, no number below zero")
print(x)
# Out:
# 4
# 4

# %%
# Only print integers
try:
  x = int(input("Enter a number: "))
except ValueError:
    raise TypeError("Only integers are allowed")  # This raises a general exception with the message "An error occurred"

print(type(x))
# Out:
# Enter a number: j
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-106469a576e8> in <cell line: 2>()
#       2 try:
# ----> 3   x = int(input("Enter a number: "))
#       4 except ValueError:
#
# ValueError: invalid literal for int() with base 10: 'j'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-106469a576e8> in <cell line: 2>()
#       3   x = int(input("Enter a number: "))
#       4 except ValueError:
# ----> 5     raise TypeError("Only integers are allowed")  # This raises a general exception with the message "An error occurred"
#       6
#       7 print(type(x))
#
# TypeError: Only integers are allowed

# %%
speed = int(input("Enter the car's speed (km/h): "))

if speed > 120:
   raise Exception("Overspeeding! slow down.")
elif speed < 20:
   raise Exception("Driving too slow! speed up.")
else:
   print(f"Speed {speed} km/h is within the acceptable range.")
# Out:
# Enter the car's speed (km/h): 280
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-31811471a1ca> in <cell line: 3>()
#       2
#       3 if speed > 120:
# ----> 4    raise Exception("Overspeeding! slow down.")
#       5 elif speed < 20:
#       6    raise Exception("Driving too slow! speed up.")
#
# Exception: Overspeeding! slow down.

# %% [markdown]
# # class

# %%
class AgeError(Exception):
  # Raise when person age is less than 18
  pass
try:
  age = int(input())
  if age < 18:
    raise AgeError

except AgeError:
  print("not eligible to vote")
else:
  print("eligible to vote")
# Out:
# 6
# not eligible to vote

# %%
class Adult_error(Exception):
  pass
try:
  age = int(input())
  if age

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
def draw_h_pattern():
    # Top Pyramid
    for i in range(1, 6):
        spaces = ' ' * (5 - i)
        stars = 'H' * (2 * i - 1)
        print(spaces + stars)

    # Two vertical blocks of H
    for _ in range(7):
        print('  HHHHH               HHHHH')

    # Middle wide block
    for _ in range(3):
        print('  HHHHHHHHHHHHHHHHHHHHHHHHHHHHH')

    # Two vertical blocks of H again
    for _ in range(7):
        print('  HHHHH               HHHHH')

    # Bottom inverted pyramid
    for i in range(5, 0, -1):
        spaces = ' ' * (5 - i)
        stars = '    H    ' * (2 * i - 1)
        print(spaces + stars)

# Call the function
draw_h_pattern()
# Out:
#     H
#    HHH
#   HHHHH
#  HHHHHHH
# HHHHHHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#     H        H        H        H        H        H        H        H        H
#      H        H        H        H        H        H        H
#       H        H        H        H        H
#        H        H        H
#         H

# %%
def print_reverse_pyramid():
    # Loop to print the inverted pyramid
    for i in range(5, 0, -1):  # Start from 5 and go down to 1
        spaces = ' ' * (5 - i)  # Number of spaces decreases as i increases
        stars = 'H' * (2 * i - 1)  # The number of 'H' increases
        print(spaces + stars)

# Call the function
print_reverse_pyramid()
# Out:
# HHHHHHHHH
#  HHHHHHH
#   HHHHH
#    HHH
#     H
