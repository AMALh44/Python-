# %% [markdown]
# # file_handling

# %%
open("file_handling","a")
open("file_handling","r")
open("file_handling","w")
# Out:
# <_io.TextIOWrapper name='file_handling' mode='w' encoding='UTF-8'>

# %%
f=open("/content/sample_data/file_handling","w")
f.write("hello world\nlukknjknlnkm")
f=open("/content/sample_data/file_handling","r")
print(f.read())
# Out:
# hello world
# lukknjknlnkm

# %%
f=open("/content/sample_data/file_handling","w")
f.write("hello world\nlukknjknlnkm")
f=open("/content/sample_data/file_handling","r")
print(f.read(3))
# Out:
# hel

# %%
f=open("/content/sample_data/file_handling","w")
f.write("helo world\nfehffrhuieuiifuu")
f=open("/content/sample_data/file_handling","r")
print(f.readline())
# Out:
# helo world

# %%
f=open("/content/sample_data/file_handling","w")
f.write("hello world\nlukknjknlnkm")
f=open("/content/sample_data/file_handling","a")
f.write("\namal")
f=open("/content/sample_data/file_handling","r")
print(f.read())
# Out:
# hello world
# lukknjknlnkm
# amal

# %%
newfile=("file1","x")

# %%
import os
os.remove("/content/sample_data/file_handling")
